# %%
dataset_id = "extracreddataset1"

# %%
# !bq --location=US mk --dataset {dataset_id}
# Out:
# Dataset 'first-planet-266901:extracreddataset1' successfully created.

# %%
# !bq --location=US load --autodetect --skip_leading_rows=1 --source_format=CSV {dataset_id}.coronabycountry 'gs://extra-cred/extracred.csv'
# Out:
# Waiting on bqjob_r3e7d53b22356849_0000017200082290_1 ... (1s) Current status: DONE

# %%
# %%bigquery
# select * from extracreddataset1.coronabycountry
# limit 3
# Out:
#          date  day  month  year  daily_confirmed_cases  daily_deaths  \
# 0  2019-12-31   31     12  2019                      0             0
# 1  2019-12-31   31     12  2019                      0             0
# 2  2019-12-31   31     12  2019                      0             0
#
#    confirmed_cases  deaths countries_and_territories geo_id  \
# 0                0       0      United_Arab_Emirates     AE
# 1                0       0               Afghanistan     AF
# 2                0       0                   Armenia     AM
#
#   country_territory_code  pop_data_2018
# 0                    ARE        9630959
# 1                    AFG       37172386
# 2                    ARM        2951776

# %%
# %%bigquery
# select * from extracreddataset1.coronabycountry where countries_and_territories = "Italy" order by year
# Out:
#            date  day  month  year  daily_confirmed_cases  daily_deaths  \
# 0    2019-12-31   31     12  2019                      0             0
# 1    2020-01-01    1      1  2020                      0             0
# 2    2020-01-02    2      1  2020                      0             0
# 3    2020-01-03    3      1  2020                      0             0
# 4    2020-01-04    4      1  2020                      0             0
# ..          ...  ...    ...   ...                    ...           ...
# 127  2020-05-06    6      5  2020                   1075           236
# 128  2020-05-07    7      5  2020                   1444           369
# 129  2020-05-08    8      5  2020                   1401           274
# 130  2020-05-09    9      5  2020                   1327           243
# 131  2020-05-10   10      5  2020                   1083           194
#
#      confirmed_cases  deaths countries_and_territories geo_id  \
# ...
